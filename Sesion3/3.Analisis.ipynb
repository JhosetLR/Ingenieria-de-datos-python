# %%
import sqlalchemy as db
import pandas as pd

engine = db.create_engine('mysql+mysqlconnector://root:root@localhost:3310/retail_db')
conn = engine.connect()

# %%
df_customers = pd.read_sql_table('customers', con=conn)
df_orders = pd.read_sql_table('orders', con=conn)
df_order_items = pd.read_sql_table('order_items', con=conn)
df_products = pd.read_sql_table('products', con=conn)
df_categories = pd.read_sql_table('categories', con=conn)
df_departments = pd.read_sql_table('departments', con=conn)

# %%
print(f'Número de clientes únicos: {df_customers["customer_id"].nunique()}')
# Out:
# Número de clientes únicos: 12435

# %%
print(df_customers['customer_state'].value_counts())
# Out:
# customer_state
# PR    4771
# CA    2012
# NY     775
# TX     635
# IL     523
# FL     374
# OH     276
# PA     261
# MI     254
# NJ     219
# AZ     213
# GA     169
# MD     164
# NC     150
# VA     136
# CO     122
# OR     119
# MA     113
# TN     104
# NV     103
# MO      92
# HI      87
# NM      73
# CT      73
# WA      72
# UT      69
# WI      64
# LA      63
# DC      42
# SC      41
# IN      40
# MN      39
# KY      35
# KS      29
# DE      23
# OK      19
# WV      16
# RI      15
# ND      14
# AR      12
# ID       9
# MT       7
# IA       5
# AL       3
# Name: count, dtype: int64

# %%
df_products['product_price']
# Out:
# 0        59.98
# 1       129.99
# 2        89.99
# 3        89.99
# 4       199.99
#          ...
# 1340     34.00
# 1341     32.00
# 1342    100.00
# 1343    100.00
# 1344    100.00
# Name: product_price, Length: 1345, dtype: float64

# %%
df_products['product_price']. idxmax()
# Out:
# 207

# %%
# Cuales son los productos más caros y mas baratos

df_products.loc[df_products['product_price'].idxmax()]
# Out:
# product_id                                                           208
# product_category_id                                                   10
# product_name                                         SOLE E35 Elliptical
# product_description
# product_price                                                    1999.99
# product_image          http://images.acmesports.sports/SOLE+E35+Ellip...
# Name: 207, dtype: object

# %%
# Cuales son los productos más caros y mas baratos

df_products.loc[df_products['product_price']. idxmin()]
# Out:
# product_id                                                            38
# product_category_id                                                    3
# product_name               Nike Men's Hypervenom Phantom Premium FG Socc
# product_description
# product_price                                                        0.0
# product_image          http://images.acmesports.sports/Nike+Men%27s+H...
# Name: 37, dtype: object

# %%
df_products.nlargest(10, 'product_price')
# Out:
#       product_id  product_category_id  \
# 207          208                   10
# 65            66                    4
# 198          199                   10
# 495          496                   22
# 1047        1048                   47
# 59            60                    4
# 196          197                   10
# 487          488                   22
# 693          694                   32
# 694          695                   32
#
#                                        product_name product_description  \
# 207                             SOLE E35 Elliptical
# 65                               SOLE F85 Treadmill
# 198                              SOLE F85 Treadmill
# 495                              SOLE F85 Treadmill
# 1047  Spalding Beast 60" Glass Portable Basketball
# 59                              SOLE E25 Elliptical
# 196                             SOLE E25 Elliptical
# 487                             SOLE E25 Elliptical
# ...

# %%
df_products.nsmallest(10, 'product_price')
# Out:
#       product_id  product_category_id  \
# 37            38                    3
# 387          388                   18
# 413          414                   19
# 516          517                   24
# 546          547                   25
# 933          934                   42
# 1283        1284                   57
# 623          624                   29
# 814          815                   37
# 335          336                   15
#
#                                        product_name product_description  \
# 37    Nike Men's Hypervenom Phantom Premium FG Socc
# 387   Nike Men's Hypervenom Phantom Premium FG Socc
# 413   Nike Men's Hypervenom Phantom Premium FG Socc
# 516   Nike Men's Hypervenom Phantom Premium FG Socc
# 546   Nike Men's Hypervenom Phantom Premium FG Socc
# 933                           Callaway X Hot Driver
# 1283  Nike Men's Hypervenom Phantom Premium FG Socc
# 623              adidas Batting Helmet Hardware Kit
# ...
